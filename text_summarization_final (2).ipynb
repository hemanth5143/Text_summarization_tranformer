# %%
import pandas as pd

# %%
data = pd.read_excel('/content/Inshorts Cleaned Data.xlsx')
data
# Out:
#                                                 Headline  \
# 0      4 ex-bank officials booked for cheating bank o...
# 1         Supreme Court to go paperless in 6 months: CJI
# 2      At least 3 killed, 30 injured in blast in Sylh...
# 3      Why has Reliance been barred from trading in f...
# 4      Was stopped from entering my own studio at Tim...
# ...                                                  ...
# 55099         Sensex loses 400 points to hit 52-week low
# 55100      China to inject $91 bn into the money markets
# 55101   Ghulam Ali set to make acting debut in Bollywood
# 55102       IS acknowledges death of Jihadi John: Report
# 55103        Cairn to seek $600 mn from India in damages
#
#                                                    Short  \
# 0      The CBI on Saturday booked four former officia...
# 1      Chief Justice JS Khehar has said the Supreme C...
# 2      At least three people were killed, including a...
# 3      Mukesh Ambani-led Reliance Industries (RIL) wa...
# 4      TV news anchor Arnab Goswami has said he was t...
# ...                                                  ...
# 55099  Tracking weak cues from the Asian markets, the...
# 55100  Amid growing concerns about China&#39;s econom...
# 55101  Pakistani Ghazal singer Ghulam Ali will soon m...
# 55102  The Islamic State (IS) has acknowledged the de...
# 55103  UK-based oil firm Cairn Energy on Tuesday said...
#
#                       Source      Time  Publish Date
# 0      The New Indian Express  09:25:00   2017-03-26
# 1                     Outlook  22:18:00   2017-03-25
# 2             Hindustan Times  23:39:00   2017-03-25
# 3                    Livemint  23:08:00   2017-03-25
# 4                     YouTube  23:24:00   2017-03-25
# ...                       ...       ...          ...
# 55099   The Financial Express  10:36:00   2016-01-20
# 55100                 Reuters  12:06:00   2016-01-20
# 55101         Hindustan Times  12:10:00   2016-01-20
# 55102                 YouTube  11:53:00   2016-01-20
# 55103                PTI News  20:50:00   2016-01-19
#
# [55104 rows x 5 columns]

# %%
data = data.rename(columns={"Headline":"target_text", "Short":"source_text"})
data = data[['source_text', 'target_text']]

# %%
data
# Out:
#                                              source_text  \
# 0      The CBI on Saturday booked four former officia...
# 1      Chief Justice JS Khehar has said the Supreme C...
# 2      At least three people were killed, including a...
# 3      Mukesh Ambani-led Reliance Industries (RIL) wa...
# 4      TV news anchor Arnab Goswami has said he was t...
# ...                                                  ...
# 55099  Tracking weak cues from the Asian markets, the...
# 55100  Amid growing concerns about China&#39;s econom...
# 55101  Pakistani Ghazal singer Ghulam Ali will soon m...
# 55102  The Islamic State (IS) has acknowledged the de...
# 55103  UK-based oil firm Cairn Energy on Tuesday said...
#
#                                              target_text
# 0      4 ex-bank officials booked for cheating bank o...
# 1         Supreme Court to go paperless in 6 months: CJI
# 2      At least 3 killed, 30 injured in blast in Sylh...
# 3      Why has Reliance been barred from trading in f...
# 4      Was stopped from entering my own studio at Tim...
# ...                                                  ...
# 55099         Sensex loses 400 points to hit 52-week low
# 55100      China to inject $91 bn into the money markets
# 55101   Ghulam Ali set to make acting debut in Bollywood
# 55102       IS acknowledges death of Jihadi John: Report
# 55103        Cairn to seek $600 mn from India in damages
#
# [55104 rows x 2 columns]

# %%
data['source_text'] = "summarize: " + data['source_text']
data
# Out:
#                                              source_text  \
# 0      summarize: The CBI on Saturday booked four for...
# 1      summarize: Chief Justice JS Khehar has said th...
# 2      summarize: At least three people were killed, ...
# 3      summarize: Mukesh Ambani-led Reliance Industri...
# 4      summarize: TV news anchor Arnab Goswami has sa...
# ...                                                  ...
# 55099  summarize: Tracking weak cues from the Asian m...
# 55100  summarize: Amid growing concerns about China&#...
# 55101  summarize: Pakistani Ghazal singer Ghulam Ali ...
# 55102  summarize: The Islamic State (IS) has acknowle...
# 55103  summarize: UK-based oil firm Cairn Energy on T...
#
#                                              target_text
# 0      4 ex-bank officials booked for cheating bank o...
# 1         Supreme Court to go paperless in 6 months: CJI
# 2      At least 3 killed, 30 injured in blast in Sylh...
# 3      Why has Reliance been barred from trading in f...
# 4      Was stopped from entering my own studio at Tim...
# ...                                                  ...
# 55099         Sensex loses 400 points to hit 52-week low
# 55100      China to inject $91 bn into the money markets
# 55101   Ghulam Ali set to make acting debut in Bollywood
# 55102       IS acknowledges death of Jihadi John: Report
# 55103        Cairn to seek $600 mn from India in damages
#
# [55104 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(data, test_size=0.1)
train_df.shape, test_df.shape
# Out:
# ((49593, 2), (5511, 2))

# %%
! pip install simplet5 -q
# Out:
#      |████████████████████████████████| 1.3 MB 9.1 MB/s
#      |████████████████████████████████| 3.5 MB 58.6 MB/s
#      |████████████████████████████████| 527 kB 80.9 MB/s
#      |████████████████████████████████| 952 kB 59.2 MB/s
#      |████████████████████████████████| 512 kB 79.6 MB/s
#      |████████████████████████████████| 829 kB 71.5 MB/s
#      |████████████████████████████████| 880 kB 73.2 MB/s
#      |████████████████████████████████| 7.6 MB 47.9 MB/s
#      |████████████████████████████████| 182 kB 80.7 MB/s
#   Building wheel for simplet5 (setup.py) ... done
#   Building wheel for future (setup.py) ... done
#   Building wheel for sacremoses (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.

# %%
from simplet5 import SimpleT5

model = SimpleT5()
model.from_pretrained(model_type="t5", model_name="t5-base")
# Out:
# INFO:pytorch_lightning.utilities.seed:Global seed set to 42
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]

# %%
model.train(train_df=train_df[:],
            eval_df=test_df[:1000], 
            source_max_token_len=128, 
            target_max_token_len=50, 
            batch_size=8, max_epochs=2, use_gpu=True)
# Out:
# INFO:pytorch_lightning.utilities.distributed:GPU available: True, used: True
# INFO:pytorch_lightning.utilities.distributed:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.distributed:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.accelerators.gpu:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# WARNING:pytorch_lightning.loggers.tensorboard:Missing logger folder: /content/lightning_logs
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name  | Type                       | Params
# -----------------------------------------------------
# 0 | model | T5ForConditionalGeneration | 222 M
# -----------------------------------------------------
# 222 M     Trainable params
# 0         Non-trainable params
# 222 M     Total params
# 891.614   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.seed:Global seed set to 42
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]

# %%
! ( cd outputs; ls )
# Out:
# simplet5-epoch-0-train-loss-1.262-val-loss-1.0344
# simplet5-epoch-1-train-loss-1.0092-val-loss-0.9949

# %%
# let's load the trained model from the local output folder for inferencing:
model.load_model("t5","/content/outputs/simplet5-epoch-1-train-loss-1.0092-val-loss-0.9949", use_gpu=False)

# %%
test_df
# Out:
#                                              source_text  \
# 46112  summarize: The Election Commission on Saturday...
# 49888  summarize: ISRO on Thursday signed an MoU with...
# 45831  summarize: The National Green Tribunal (NGT) o...
# 34419  summarize: At least 11 people died and 19 were...
# 31376  summarize: Lionel Messi&#39;s three-year-old s...
# ...                                                  ...
# 15939  summarize: The captain of the Southwest Airlin...
# 12568  summarize: After SP MLA Abu Azmi said women co...
# 53007  summarize: BJP leader Shahnawaz Hussain on Wed...
# 45337  summarize: The BSE Sensex and the NSE Nifty on...
# 37380  summarize: Mahindra &amp; Mahindra&#39;s Execu...
#
#                                              target_text
# 46112    FIR against TMC leader for threat to CPI(M) men
# 49888                ISRO signs MoU with Indian Railways
# 45831  NGT issues notice to U&#39;khand, HP for fores...
# 34419     11 dead in air strike on MSF hospital in Yemen
# 31376  Lionel Messi&#39;s son to join Barcelona&#39;s...
# ...                                                  ...
# 15939  Pilot congratulates travellers for having all ...
# 12568  Abu Azmi&#39;s son, Esha Gupta engage in twitt...
# 53007               Rahul obsessed with Modi: BJP leader
# 45337    Sensex up 460 points; Nifty rises by 132 points
# 37380  &#39;Mahindra&#39;s 2-wheeler segment hasn&#39...
#
# [5511 rows x 2 columns]

# %%
text_to_summarize = []
for i in test_df['source_text']:
  text_to_summarize.append(i)

# %%
summary = []
for i in test_df['target_text']:
  summary.append(i)

# %%
trail_sor = text_to_summarize[:100]
trail_summ = summary[:100]

# %%
from nltk.translate.bleu_score import sentence_bleu
from nltk.translate.bleu_score import SmoothingFunction
smoothie = SmoothingFunction().method4

# %%
testt = pd.DataFrame(summary[:])

# %%
predicted_summaries = [] 
for i in text_to_summarize:
  k = model.predict(i)
  predicted_summaries.append(k)

# %%
def bleu_score(reference,candidate):
  bscore=0
  for i in range(len(predicted_summaries)-1):
    reference = [str(ref[i]).split()]
    candidate = str(can[i]).split()
    score = sentence_bleu(reference,candidate,weights=(1, 0, 0, 0))
  return score

# %%
ref = testt[0]
can = predicted_summaries[:]
bleu_score(ref,can)
# Out:
# 0.6666666666666666

# %%
pred_data = pd.DataFrame()
pred_data['summary'] = summary
pred_data['predicted'] = predicted_summaries
pred_data
# Out:
#                                                 summary  \
# 0       FIR against TMC leader for threat to CPI(M) men
# 1                   ISRO signs MoU with Indian Railways
# 2     NGT issues notice to U&#39;khand, HP for fores...
# 3        11 dead in air strike on MSF hospital in Yemen
# 4     Lionel Messi&#39;s son to join Barcelona&#39;s...
# ...                                                 ...
# 5506  Pilot congratulates travellers for having all ...
# 5507  Abu Azmi&#39;s son, Esha Gupta engage in twitt...
# 5508               Rahul obsessed with Modi: BJP leader
# 5509    Sensex up 460 points; Nifty rises by 132 points
# 5510  &#39;Mahindra&#39;s 2-wheeler segment hasn&#39...
#
#                                               predicted
# 0                   [EC orders FIR against Sonali Guha]
# 1          [ISRO, Railways sign MoU for remote sensing]
# 2       [NGT issues show cause notices to UP, Himachal]
# 3         [Saudi-led air strike hits hospital in Yemen]
# 4     [Messi&#39;s 3-year-old son to join Barcelona&...
# ...                                                 ...
# 5506  [Southwest Airlines captain congratulates pass...
# 5507  [Farhan Azmi engages in war of words with Esha...
# 5508  [Rahul Gandhi is obsessed with PM Modi: Shahna...
# 5509  [Sensex gains 460 points; Nifty up by 132 points]
# 5510  [Mahindra&#39;s two-wheeler segment has not me...
#
# [5511 rows x 2 columns]
